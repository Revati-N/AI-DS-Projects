# %% [markdown]
# # Multi-Search Agent using RAG

# %% [markdown]
# **Tools**
#
# Tools are utilities designed to be called by a model: their inputs are designed to be generated by models, and their outputs are designed to be passed back to models.
#
# A toolkit is a collection of tools meant to be used together.

# %%
# !pip install arxiv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: arxiv in c:\users\revna\appdata\roaming\python\python312\site-packages (2.2.0)
# Requirement already satisfied: feedparser~=6.0.10 in c:\users\revna\appdata\roaming\python\python312\site-packages (from arxiv) (6.0.11)
# Requirement already satisfied: requests~=2.32.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from arxiv) (2.32.3)
# Requirement already satisfied: sgmllib3k in c:\users\revna\appdata\roaming\python\python312\site-packages (from feedparser~=6.0.10->arxiv) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests~=2.32.0->arxiv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests~=2.32.0->arxiv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests~=2.32.0->arxiv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests~=2.32.0->arxiv) (2024.12.14)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
