# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

models = ['DT', 'SVM', 'AdaB', 'XGB', 'LDA', 'Per', 'KNN', 'NB', 'RF', 'LR', 'ET']

accuracy_models = [0.96, 0.92, 0.9, 0.995, 0.91, 0.89, 0.89, 0.933, 0.98, 0.96, 0.973]

ax.bar(models, accuracy_models, color = 'deepskyblue')
ax.set_title("Accuracy of Standalone Models")
ax.set_xlabel("Models")
ax.set_ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
fig, ax = plt.subplots()

models = ['DT', 'SVM', 'AdaB', 'XGB', 'LDA', 'Per', 'KNN', 'NB', 'RF', 'LR', 'ET']

precision = [0.95, 0.93, 0.89, 0.995, 0.88, 0.89, 0.89, 0.933, 0.98, 0.96, 0.973]

ax.bar(models, precision, color = 'dodgerblue')
ax.set_title("Precision of Standalone Models")
ax.set_xlabel("Models")
ax.set_ylabel("Precision")
# Out:
# Text(0, 0.5, 'Precision')

# %%
fig, ax = plt.subplots()

models = ['DT', 'SVM', 'AdaB', 'XGB', 'LDA', 'Per', 'KNN', 'NB', 'RF', 'LR', 'ET']

precision =  [0.95, 0.92, 0.9, 0.995, 0.89, 0.89, 0.89, 0.932, 0.936, 0.954, 0.975]

ax.bar(models, precision, color = 'steelblue')
ax.set_title("F1-Score of Standalone Models")
ax.set_xlabel("Models")
ax.set_ylabel("F1-Score")
# Out:
# Text(0, 0.5, 'F1-Score')

# %%
fig, ax = plt.subplots()

models = ['DT', 'SVM', 'AdaB', 'XGB', 'LDA', 'Per', 'KNN', 'NB', 'RF', 'LR', 'ET']

precision =   [0.8, 0.71, 0.63, 0.981, 0.61, 0.62, 0.62, 0.789, 0.923, 0.813, 0.883]

ax.bar(models, precision, color = 'navy')
ax.set_title("Kappa Index of Standalone Models")
ax.set_xlabel("Models")
ax.set_ylabel("Kappa Index")
# Out:
# Text(0, 0.5, 'Kappa Index')

# %%
fig, ax = plt.subplots()

models = ['DT', 'SVM', 'AdaB', 'XGB', 'LDA', 'Per', 'KNN', 'NB', 'RF', 'LR', 'ET']

precision =  [0.94, 0.92, 0.9, 0.995, 0.91, 0.89, 0.89, 0.933, 0.976, 0.956, 0.973]

ax.bar(models, precision, color = 'darkcyan')
ax.set_title("Recall of Standalone Models")
ax.set_xlabel("Models")
ax.set_ylabel("Recall")
# Out:
# Text(0, 0.5, 'Recall')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your data
before = [0.9374, 0.933, 0.933, 0.761, 0.935]
after = [0.94, 0.959, 0.9545, 0.841, 0.9573]
stack = [0.995, 0.99525, 0.995, 0.98143, 0.995]

# Attribute names
attributes = ['Accuracy','Precision','F1-Score','Kappa Index','Recall']

# Define the color for each sample
colors = ['royalblue','orangered','goldenrod']  # red for before, green for after, blue for stack

# Create an array with the positions of each bar along the x-axis
x = np.arange(len(attributes))

# Create the figure and the axes
fig, ax = plt.subplots()

# Plot each sample
ax.bar(x - 0.3, before, 0.3, color=colors[0], label='Before Attribute Selection')
ax.bar(x, after, 0.3, color=colors[1], label='After Attribute Selection')
ax.bar(x + 0.3, stack, 0.3, color=colors[2], label='After Stacking')

# Add a legend
ax.legend(loc = 'lower right')

# Replace the x-ticks with the attribute names
ax.set_xticks(x)
ax.set_xticklabels(attributes)

ax.set_title("Comparison of Results Obtained")
ax.set_xlabel("Evaluation Metrics")
ax.set_ylabel("Results")

plt.show()
